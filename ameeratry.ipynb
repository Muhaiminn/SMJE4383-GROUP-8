# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhaiminn/SMJE4383-GROUP-8/blob/main/ameeratry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int (input ("Give a number"))
b,c = 1,0
while b<= a:
  c = c + b
  b = b + 1
  print (a, b, c)
  print ("result: ", float (c)/(b-1))
# Out:
# Give a number6
# 6 2 1
# result:  1.0
# 6 3 3
# result:  1.5
# 6 4 6
# result:  2.0
# 6 5 10
# result:  2.5
# 6 6 15
# result:  3.0
# 6 7 21
# result:  3.5
